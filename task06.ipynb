# %% [markdown]
# ## Task 6. Bonus
# #### Name: Harinya Potluri
# #### Date: 09/23/2023

# %% [markdown]
# ## import the csv dataset into a DataFrame using Pandas

# %%
import pandas as pd

df = pd.read_csv("WeatherEvents_Jan2016-Dec2022.csv")

df.head()
# Out:
#   EventId  Type Severity       StartTime(UTC)         EndTime(UTC)  \
# 0     W-1  Snow    Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1     W-2  Snow    Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2     W-3  Snow    Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3     W-4  Snow    Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4     W-5  Snow    Light  2016-01-08 13:54:00  2016-01-08 15:54:00
#
#    Precipitation(in)     TimeZone AirportCode  LocationLat  LocationLng  \
# 0               0.00  US/Mountain        K04V      38.0972    -106.1689
# 1               0.00  US/Mountain        K04V      38.0972    -106.1689
# 2               0.03  US/Mountain        K04V      38.0972    -106.1689
# 3               0.00  US/Mountain        K04V      38.0972    -106.1689
# 4               0.00  US/Mountain        K04V      38.0972    -106.1689
#
#        City    County State  ZipCode
# 0  Saguache  Saguache    CO  81149.0
# 1  Saguache  Saguache    CO  81149.0
# ...

# %% [markdown]
# ## Using DataFrame commands to clean the data as needed and/or rename the columns

# %%
df.rename(columns = {'LocationLat':'Latitude', 'LocationLng': 'Longitude'}, inplace = True)

df.head()
# Out:
#   EventId  Type Severity       StartTime(UTC)         EndTime(UTC)  \
# 0     W-1  Snow    Light  2016-01-06 23:14:00  2016-01-07 00:34:00
# 1     W-2  Snow    Light  2016-01-07 04:14:00  2016-01-07 04:54:00
# 2     W-3  Snow    Light  2016-01-07 05:54:00  2016-01-07 15:34:00
# 3     W-4  Snow    Light  2016-01-08 05:34:00  2016-01-08 05:54:00
# 4     W-5  Snow    Light  2016-01-08 13:54:00  2016-01-08 15:54:00
#
#    Precipitation(in)     TimeZone AirportCode  Latitude  Longitude      City  \
# 0               0.00  US/Mountain        K04V   38.0972  -106.1689  Saguache
# 1               0.00  US/Mountain        K04V   38.0972  -106.1689  Saguache
# 2               0.03  US/Mountain        K04V   38.0972  -106.1689  Saguache
# 3               0.00  US/Mountain        K04V   38.0972  -106.1689  Saguache
# 4               0.00  US/Mountain        K04V   38.0972  -106.1689  Saguache
#
#      County State  ZipCode
# 0  Saguache    CO  81149.0
# 1  Saguache    CO  81149.0
# ...

# %% [markdown]
# ## Using DataFrame describe() function to calculate basic descriptive statistics.

# %%
df.describe()
# Out:
#        Precipitation(in)      Latitude     Longitude       ZipCode
# count       8.627181e+06  8.627181e+06  8.627181e+06  8.557982e+06
# mean        9.287441e-02  3.878602e+01 -9.191172e+01  5.241150e+04
# std         8.870326e-01  5.467708e+00  1.350340e+01  2.573249e+04
# min         0.000000e+00  2.455710e+01 -1.245550e+02  1.022000e+03
# 25%         0.000000e+00  3.459950e+01 -9.782360e+01  3.121600e+04
# 50%         0.000000e+00  3.934510e+01 -8.977340e+01  5.391300e+04
# 75%         5.000000e-02  4.306220e+01 -8.194720e+01  7.350300e+04
# max         1.104130e+03  4.894020e+01 -6.779280e+01  9.936200e+04

# %% [markdown]
# ## Using the DataFrame hist() function to generate histograms for all numeric columns.

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Precipitation(in)'}>,
#         <Axes: title={'center': 'Latitude'}>],
#        [<Axes: title={'center': 'Longitude'}>,
#         <Axes: title={'center': 'ZipCode'}>]], dtype=object)
